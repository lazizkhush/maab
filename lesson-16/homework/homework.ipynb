# %%
import pandas as pd
import sqlite3

# %%
with sqlite3.connect('../data/chinook.db') as con:
    data = pd.read_sql("SELECT * FROM Customers", con)

data.head(10)
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# ...

# %%
data = pd.read_json('../data/iris.json')
print(data.shape)
# Out:
# (150, 5)

# %%
data_xls = pd.read_excel('../data/titanic.xlsx')
data_xls.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data_parq = pd.read_parquet('../data/flights')
data_parq.info()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data_parq = pd.read_parquet('../data/flights')
#       2 data_parq.info()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...

# %%
movie_data = pd.read_csv('../data/movie.csv')
movie_data.sample(10)
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 3865  Color  Jorge Ramírez Suárez                    26.0     120.0
# 1886  Color       Martin Scorsese                   192.0     146.0
# 1745  Color        Shinji Aramaki                    62.0     115.0
# 2997  Color       Stanley Kubrick                   124.0     184.0
# 1344  Color           Lee Daniels                   323.0     109.0
# 4527  Color       Allison Burnett                     8.0     100.0
# 4874  Color          Travis Legge                     2.0      83.0
# 2194  Color      John Schlesinger                    31.0     101.0
# 1848  Color    Fernando Meirelles                   226.0     129.0
# 4395  Color     Quentin Tarantino                   173.0      99.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 3865                     45.0                    69.0   Adriana Barraza
# 1886                  17000.0                   635.0        Mike Starr
# ...

# %%
data_iris = pd.read_json('../data/iris.json')
data_iris.columns = [column.lower() for column in data_iris.columns]
print(data_iris[['sepallength', 'sepalwidth']])
# Out:
#      sepallength  sepalwidth
# 0            5.1         3.5
# 1            4.9         3.0
# 2            4.7         3.2
# 3            4.6         3.1
# 4            5.0         3.6
# ..           ...         ...
# 145          6.7         3.0
# 146          6.3         2.5
# 147          6.5         3.0
# 148          6.2         3.4
# 149          5.9         3.0
#
# [150 rows x 2 columns]

# %%
data_titanic = pd.read_excel('../data/titanic.xlsx')
print(data_titanic[data_titanic['Age']>30])
genders = data_titanic['Sex'].value_counts()
print(genders)
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
selected_columns = data_parq[['origin', 'dest', 'carrier']]
print(selected_columns)
# Find the number of unique destinations
unique_destinations = selected_columns['dest'].nunique()
print(unique_destinations)

# %%
iris_numerical = data_iris.select_dtypes('number')

print('Mean:')
print(iris_numerical.mean())
print('STD:')
print(iris_numerical.std())
print('Median:')
print(iris_numerical.median())
# Out:
# Mean:
# sepallength    5.843333
# sepalwidth     3.057333
# petallength    3.758000
# petalwidth     1.199333
# dtype: float64
# STD:
# sepallength    0.828066
# sepalwidth     0.435866
# petallength    1.765298
# petalwidth     0.762238
# dtype: float64
# Median:
# sepallength    5.80
# sepalwidth     3.00
# petallength    4.35
# petalwidth     1.30
# dtype: float64

# %%
min_age = data_titanic['Age'].min()
max_age = data_titanic['Age'].max()
sum_age = data_titanic['Age'].sum()
print(f'{min_age=}')
print(f'{max_age=}')
print(f'{sum_age=}')
# Out:
# min_age=np.float64(0.42)
# max_age=np.float64(80.0)
# sum_age=np.float64(21205.17)

# %%
data_movies = pd.read_csv('../data/movie.csv')
director_name = data_movies.groupby('director_name')['director_facebook_likes'].sum().idxmax()
likes = data_movies.groupby('director_name')['director_facebook_likes'].sum().max()
print(f'{director_name}, {likes} likes')
longest_movies = data_movies.nlargest(5, 'duration')
drs_with_longest_movies = longest_movies['director_name']
print(drs_with_longest_movies)
# Out:
# Steven Spielberg, 364000.0 likes
# 1694                    NaN
# 2436                    NaN
# 1487        Taylor Hackford
# 1134         Michael Cimino
# 3254    Chatrichalerm Yukol
# Name: director_name, dtype: object

# %%
data_parq.fillna(data_parq.mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 data_parq.fillna(data_parq.mean(), inplace=True)
#
# NameError: name 'data_parq' is not defined
